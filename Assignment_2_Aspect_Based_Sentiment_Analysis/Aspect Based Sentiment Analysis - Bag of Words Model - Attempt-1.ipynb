# %% [markdown]
# ### Importing Libraries

# %%
import numpy as np
import pandas as pd
import spacy
from keras.models import load_model
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.preprocessing.text import Tokenizer
from sklearn.preprocessing import LabelEncoder
from keras.utils import to_categorical
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### Analyze Dataset

# %%
train_dataset = '/home/ayush/Graduate_Study/Natural_Language_Processing_Course/Assignment_2/exercise2/data/traindata.csv'
dev_dataset = '/home/ayush/Graduate_Study/Natural_Language_Processing_Course/Assignment_2/exercise2/data/devdata.csv'

# %%
col_names = ['Polarity','Aspect_Category','Specific_Target_Aspect_Term','Character_Offset','Sentence']
train_df = pd.read_csv(train_dataset,sep='\t',names=col_names)
dev_df = pd.read_csv(dev_dataset,sep='\t',names=col_names)

spacy_parser = spacy.load('en')
vocab_size = 8000
num_aspect_categories = 12 # There are 12 Aspect Categories
num_sentiments = 3 # Positive, Negative and Neutral

#Drop the character Offset Dataframe
train_df = train_df.drop(columns=['Character_Offset'])
dev_df = dev_df.drop(columns=['Character_Offset'])

# %%
print('Train Data Shape: ',train_df.shape)
print('Dev Data Shape: ',dev_df.shape)
# Out:
# Train Data Shape:  (1503, 4)
# Dev Data Shape:  (376, 4)

# %%
print(train_df.head(30))
# Out:
#     Polarity           Aspect_Category Specific_Target_Aspect_Term  \
# 0   positive          AMBIENCE#GENERAL                     seating
# 1   positive          AMBIENCE#GENERAL                   trattoria
# 2   positive              FOOD#QUALITY                        food
# 3   negative           SERVICE#GENERAL                       STAFF
# 4   positive        FOOD#STYLE_OPTIONS                        menu
# 5   positive              FOOD#QUALITY                        tuna
# 6   negative           SERVICE#GENERAL                       staff
# 7   negative           SERVICE#GENERAL                     service
# 8   positive        FOOD#STYLE_OPTIONS                    BBQ ribs
# 9   positive          AMBIENCE#GENERAL                       place
# 10  negative              FOOD#QUALITY         appetizer of olives
# 11  negative              FOOD#QUALITY                       foods
# 12  positive            DRINKS#QUALITY                      drinks
# 13  positive              FOOD#QUALITY                       rolls
# 14  positive              FOOD#QUALITY              Prix Fixe menu
# 15  positive              FOOD#QUALITY                    scallops
# 16  positive          AMBIENCE#GENERAL                    Ambience
# 17  positive          AMBIENCE#GENERAL       late night atmosphere
# 18  positive              FOOD#QUALITY                  pear torte
# 19  positive              FOOD#QUALITY        spicy Italian cheese
# 20  positive              FOOD#QUALITY                       filet
# 21  negative              FOOD#QUALITY                  quesadilla
# 22  negative  RESTAURANT#MISCELLANEOUS                       place
# 23  positive              FOOD#QUALITY                        food
# 24  positive           SERVICE#GENERAL                     Service
# 25  positive              FOOD#QUALITY                      bagels
# 26  negative        RESTAURANT#GENERAL                  restaurant
# 27  positive              FOOD#QUALITY                french fries
# 28  positive              FOOD#QUALITY                 rice dishes
# 29  positive          AMBIENCE#GENERAL                    ambience
#
#                                              Sentence
# 0   short and sweet – seating is great:it's romant...
# 1   This quaint and romantic trattoria is at the t...
# 2   The have over 100 different beers to offer thi...
# 3                         THIS STAFF SHOULD BE FIRED.
# 4   The menu looked great, and the waiter was very...
# 5         The tuna and wasabe potatoes are excellent.
# 6   The whole set up is truly unprofessional and I...
# 7   sometimes i get bad food and bad service, some...
# 8   This place has the best Chinese style BBQ ribs...
# 9          Great place to relax and enjoy your dinner
# 10  The bread we received was horrible - rock hard...
# 11  We thought that this place is using too much o...
# 12     Always good drinks and service is pretty good;
# 13  We are very particular about sushi and were bo...
# 14  The Prix Fixe menu is worth every penny and yo...
# 15  We had the scallops as an appetizer and they w...
# 16  Ambience is so cute and quaint, good for busin...
# 17  But the best part about LS is the late night a...
# 18  The dessert (we had a pear torte) was good - b...
# 19  The pesto pizza was excellent, thin-crust pizz...
# 20  I had fish and my husband had the filet - both...
# 21  My quesadilla tasted like it had been made by ...
# 22                     This place is incredibly tiny.
# 23  I found the food to be outstanding, particular...
# 24                  Service was prompt and courteous.
# 25  delicious bagels, especially when right out of...
# 26  I have never left a restaurant feeling as if i...
# 27  My husband said he could've eaten several more...
# 28  I also recommend the rice dishes or the differ...
# 29  I highly recommend Cafe St. Bart's for their f...

# %% [markdown]
# ### Extract Sentiment for Aspect

# %%
Specific_Target_Sentiment_Term = []
for review in spacy_parser.pipe(train_df['Sentence']):
        if review.is_parsed:
            Specific_Target_Sentiment_Term.append(' '.join([token.lemma_ for token in review if (not token.is_stop and not token.is_punct and (token.pos_ == "ADJ" or token.pos_ == "VERB"))]))
        else:
            Specific_Target_Sentiment_Term.append('')  
train_df['Specific_Target_Sentiment_Term'] = Specific_Target_Sentiment_Term
train_df.head(10)
# Out:
#    Polarity     Aspect_Category Specific_Target_Aspect_Term  \
# 0  positive    AMBIENCE#GENERAL                     seating
# 1  positive    AMBIENCE#GENERAL                   trattoria
# 2  positive        FOOD#QUALITY                        food
# 3  negative     SERVICE#GENERAL                       STAFF
# 4  positive  FOOD#STYLE_OPTIONS                        menu
# 5  positive        FOOD#QUALITY                        tuna
# 6  negative     SERVICE#GENERAL                       staff
# 7  negative     SERVICE#GENERAL                     service
# 8  positive  FOOD#STYLE_OPTIONS                    BBQ ribs
# 9  positive    AMBIENCE#GENERAL                       place
#
#                                             Sentence  \
# 0  short and sweet – seating is great:it's romant...
# 1  This quaint and romantic trattoria is at the t...
# 2  The have over 100 different beers to offer thi...
# 3                        THIS STAFF SHOULD BE FIRED.
# 4  The menu looked great, and the waiter was very...
# 5        The tuna and wasabe potatoes are excellent.
# 6  The whole set up is truly unprofessional and I...
# 7  sometimes i get bad food and bad service, some...
# 8  This place has the best Chinese style BBQ ribs...
# 9         Great place to relax and enjoy your dinner
#
#                   Specific_Target_Sentiment_Term
# 0     short sweet great be romantic cozy private
# 1                                quaint romantic
# 2  different offer thi happy delicious recommend
# 3                                      should be
# 4                   look great nice come average
# 5                                      excellent
# 6         unprofessional wish good current great
# 7                          bad bad good good bad
# 8                                   good chinese
# 9                              great relax enjoy

# %% [markdown]
# ### Building Bag of Words Representation

# %%
tokenizer = Tokenizer(num_words=vocab_size)
tokenizer.fit_on_texts(train_df.Sentence)

# %% [markdown]
# ### Encode the Aspect Categories

# %%
#label_encoder_aspect = LabelEncoder()
#aspect_integer_category = label_encoder_aspect.fit_transform(train_df.Aspect_Category)
#aspect_dummy_category = to_categorical(aspect_integer_category)

# %% [markdown]
# ### Building the Sentiment Analysis Model

# %%
sentiment_model = Sequential()
sentiment_model.add(Dense(512, input_shape=(vocab_size,), activation='relu'))
sentiment_model.add(Dense(num_sentiments, activation='softmax'))
sentiment_model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
tokenized_sentiment = pd.DataFrame(tokenizer.texts_to_matrix(train_df.Specific_Target_Sentiment_Term))

# %%
label_encoder_sentiment = LabelEncoder()
sentiment_integer_category = label_encoder_sentiment.fit_transform(train_df.Polarity)
sentiment_dummy_category = to_categorical(sentiment_integer_category)

# %%
sentiment_model.fit(tokenized_sentiment, sentiment_dummy_category, epochs=40, verbose=1)
# Out:
# Epoch 1/40
# 1503/1503 [==============================] - 2s 1ms/step - loss: 0.8127 - acc: 0.6900
# Epoch 2/40
# 1503/1503 [==============================] - 1s 997us/step - loss: 0.5152 - acc: 0.7904
# Epoch 3/40
# 1503/1503 [==============================] - 2s 1ms/step - loss: 0.3965 - acc: 0.8410
# Epoch 4/40
# 1503/1503 [==============================] - 2s 1ms/step - loss: 0.3335 - acc: 0.8689
# Epoch 5/40
# 1503/1503 [==============================] - 2s 1ms/step - loss: 0.2959 - acc: 0.8796
# Epoch 6/40
# 1503/1503 [==============================] - 2s 1ms/step - loss: 0.2710 - acc: 0.8829
# Epoch 7/40
# 1503/1503 [==============================] - 2s 1ms/step - loss: 0.2497 - acc: 0.8949
# Epoch 8/40
# 1503/1503 [==============================] - 2s 1ms/step - loss: 0.2342 - acc: 0.9009
# Epoch 9/40
# 1503/1503 [==============================] - 2s 999us/step - loss: 0.2244 - acc: 0.8955
# Epoch 10/40
# 1503/1503 [==============================] - 2s 1ms/step - loss: 0.2196 - acc: 0.8942
# Epoch 11/40
# 1503/1503 [==============================] - 2s 1ms/step - loss: 0.2084 - acc: 0.8935
# Epoch 12/40
# 1503/1503 [==============================] - 2s 1ms/step - loss: 0.2032 - acc: 0.8995
# Epoch 13/40
# 1503/1503 [==============================] - 2s 1ms/step - loss: 0.2001 - acc: 0.9042
# Epoch 14/40
# 1503/1503 [==============================] - 2s 1ms/step - loss: 0.1992 - acc: 0.8935
# Epoch 15/40
# 1503/1503 [==============================] - 2s 1ms/step - loss: 0.1942 - acc: 0.9009
# Epoch 16/40
# 1503/1503 [==============================] - 2s 1ms/step - loss: 0.1899 - acc: 0.9009
# Epoch 17/40
# 1503/1503 [==============================] - 1s 994us/step - loss: 0.1845 - acc: 0.8995
# Epoch 18/40
# 1503/1503 [==============================] - 2s 1ms/step - loss: 0.1825 - acc: 0.9062
# Epoch 19/40
# 1503/1503 [==============================] - 2s 998us/step - loss: 0.1815 - acc: 0.9002
# Epoch 20/40
# 1503/1503 [==============================] - 2s 1ms/step - loss: 0.1772 - acc: 0.9095
# Epoch 21/40
# 1503/1503 [==============================] - 2s 1ms/step - loss: 0.1783 - acc: 0.9049
# Epoch 22/40
# 1503/1503 [==============================] - 2s 1ms/step - loss: 0.1772 - acc: 0.9042
# Epoch 23/40
# 1503/1503 [==============================] - 2s 1ms/step - loss: 0.1733 - acc: 0.9102
# Epoch 24/40
# 1503/1503 [==============================] - 2s 1ms/step - loss: 0.1720 - acc: 0.9088
# Epoch 25/40
# 1503/1503 [==============================] - 2s 1ms/step - loss: 0.1701 - acc: 0.9055
# Epoch 26/40
# 1503/1503 [==============================] - 2s 1ms/step - loss: 0.1711 - acc: 0.9102
# Epoch 27/40
# 1503/1503 [==============================] - 2s 1ms/step - loss: 0.1691 - acc: 0.9115
# Epoch 28/40
# 1503/1503 [==============================] - 2s 1ms/step - loss: 0.1663 - acc: 0.9069
# Epoch 29/40
# 1503/1503 [==============================] - 2s 1ms/step - loss: 0.1683 - acc: 0.9049
# Epoch 30/40
# 1503/1503 [==============================] - 2s 1ms/step - loss: 0.1657 - acc: 0.9095
# Epoch 31/40
# 1503/1503 [==============================] - 2s 1ms/step - loss: 0.1651 - acc: 0.9062
# Epoch 32/40
# 1503/1503 [==============================] - 2s 1ms/step - loss: 0.1635 - acc: 0.9042
# Epoch 33/40
# 1503/1503 [==============================] - 2s 1ms/step - loss: 0.1633 - acc: 0.9095
# Epoch 34/40
# 1503/1503 [==============================] - 2s 1ms/step - loss: 0.1630 - acc: 0.9082
# Epoch 35/40
# 1503/1503 [==============================] - 2s 1ms/step - loss: 0.1625 - acc: 0.9062
# Epoch 36/40
# 1503/1503 [==============================] - 2s 1ms/step - loss: 0.1608 - acc: 0.9128
# Epoch 37/40
# 1503/1503 [==============================] - 2s 1ms/step - loss: 0.1627 - acc: 0.9082
# Epoch 38/40
# 1503/1503 [==============================] - 2s 1ms/step - loss: 0.1607 - acc: 0.9075A: 1s - loss:
# Epoch 39/40
# 1503/1503 [==============================] - 2s 1ms/step - loss: 0.1612 - acc: 0.9055
# Epoch 40/40
# 1503/1503 [==============================] - 2s 1ms/step - loss: 0.1611 - acc: 0.9042

# %% [markdown]
# ### Testing the ABSA Model on Validation Dataset

# %%
# Aspect preprocessing
#val_aspect_terms = pd.DataFrame(tokenizer.texts_to_matrix(val_df.Specific_Target_Aspect_Term))

dev_aspect_category = list(dev_df.Aspect_Category)
                             
# Sentiment preprocessing
Dev_Specific_Target_Sentiment_Term = []
for review in spacy_parser.pipe(dev_df['Sentence']):
        if review.is_parsed:
            Dev_Specific_Target_Sentiment_Term.append(' '.join([token.lemma_ for token in review if (not token.is_stop and not token.is_punct and (token.pos_ == "ADJ" or token.pos_ == "VERB"))]))
        else:
            Dev_Specific_Target_Sentiment_Term.append('') 
            
Dev_Specific_Target_Sentiment_Term = pd.DataFrame(tokenizer.texts_to_matrix(Dev_Specific_Target_Sentiment_Term))

# Models output
#Dev_aspect_categories = label_encoder_aspect.inverse_transform(train_df.Aspect_Category)
Dev_predict_sentiment = label_encoder_sentiment.inverse_transform(sentiment_model.predict_classes(Dev_Specific_Target_Sentiment_Term))

for i in range(len(dev_aspect_category)):
    print("Review " + str(i+1) + " is expressing a  " + Dev_predict_sentiment[i] + " opinion about " + dev_df.Aspect_Category[i])
# Out:
# Review 1 is expressing a  positive opinion about LOCATION#GENERAL
# Review 2 is expressing a  negative opinion about RESTAURANT#GENERAL
# Review 3 is expressing a  positive opinion about FOOD#QUALITY
# Review 4 is expressing a  positive opinion about SERVICE#GENERAL
# Review 5 is expressing a  positive opinion about DRINKS#QUALITY
# Review 6 is expressing a  negative opinion about AMBIENCE#GENERAL
# Review 7 is expressing a  negative opinion about RESTAURANT#GENERAL
# Review 8 is expressing a  positive opinion about SERVICE#GENERAL
# Review 9 is expressing a  positive opinion about SERVICE#GENERAL
# Review 10 is expressing a  negative opinion about RESTAURANT#MISCELLANEOUS
# Review 11 is expressing a  positive opinion about SERVICE#GENERAL
# Review 12 is expressing a  positive opinion about FOOD#STYLE_OPTIONS
# Review 13 is expressing a  positive opinion about DRINKS#QUALITY
# Review 14 is expressing a  positive opinion about FOOD#PRICES
# Review 15 is expressing a  positive opinion about FOOD#QUALITY
# Review 16 is expressing a  positive opinion about DRINKS#STYLE_OPTIONS
# Review 17 is expressing a  positive opinion about FOOD#QUALITY
# Review 18 is expressing a  positive opinion about RESTAURANT#GENERAL
# Review 19 is expressing a  positive opinion about FOOD#QUALITY
# Review 20 is expressing a  positive opinion about FOOD#QUALITY
# Review 21 is expressing a  negative opinion about SERVICE#GENERAL
# Review 22 is expressing a  positive opinion about FOOD#QUALITY
# Review 23 is expressing a  positive opinion about FOOD#STYLE_OPTIONS
# Review 24 is expressing a  negative opinion about DRINKS#STYLE_OPTIONS
# Review 25 is expressing a  positive opinion about FOOD#QUALITY
# Review 26 is expressing a  negative opinion about FOOD#QUALITY
# Review 27 is expressing a  negative opinion about RESTAURANT#PRICES
# Review 28 is expressing a  positive opinion about FOOD#QUALITY
# Review 29 is expressing a  positive opinion about LOCATION#GENERAL
# Review 30 is expressing a  positive opinion about RESTAURANT#GENERAL
# Review 31 is expressing a  negative opinion about SERVICE#GENERAL
# Review 32 is expressing a  positive opinion about FOOD#QUALITY
# Review 33 is expressing a  positive opinion about SERVICE#GENERAL
# Review 34 is expressing a  positive opinion about AMBIENCE#GENERAL
# Review 35 is expressing a  positive opinion about FOOD#QUALITY
# Review 36 is expressing a  negative opinion about FOOD#QUALITY
# Review 37 is expressing a  positive opinion about FOOD#QUALITY
# Review 38 is expressing a  positive opinion about FOOD#QUALITY
# Review 39 is expressing a  positive opinion about FOOD#QUALITY
# Review 40 is expressing a  positive opinion about FOOD#QUALITY
# Review 41 is expressing a  positive opinion about FOOD#QUALITY
# Review 42 is expressing a  positive opinion about RESTAURANT#GENERAL
# Review 43 is expressing a  negative opinion about FOOD#QUALITY
# Review 44 is expressing a  positive opinion about FOOD#STYLE_OPTIONS
# Review 45 is expressing a  positive opinion about SERVICE#GENERAL
# Review 46 is expressing a  positive opinion about FOOD#QUALITY
# Review 47 is expressing a  positive opinion about DRINKS#QUALITY
# Review 48 is expressing a  positive opinion about AMBIENCE#GENERAL
# Review 49 is expressing a  positive opinion about DRINKS#STYLE_OPTIONS
# Review 50 is expressing a  positive opinion about AMBIENCE#GENERAL
# Review 51 is expressing a  negative opinion about FOOD#QUALITY
# Review 52 is expressing a  positive opinion about FOOD#QUALITY
# Review 53 is expressing a  positive opinion about FOOD#PRICES
# Review 54 is expressing a  negative opinion about FOOD#PRICES
# Review 55 is expressing a  positive opinion about FOOD#PRICES
# Review 56 is expressing a  positive opinion about FOOD#QUALITY
# Review 57 is expressing a  positive opinion about FOOD#PRICES
# Review 58 is expressing a  positive opinion about AMBIENCE#GENERAL
# Review 59 is expressing a  positive opinion about FOOD#QUALITY
# Review 60 is expressing a  positive opinion about FOOD#QUALITY
# Review 61 is expressing a  neutral opinion about FOOD#QUALITY
# Review 62 is expressing a  positive opinion about SERVICE#GENERAL
# Review 63 is expressing a  negative opinion about FOOD#QUALITY
# Review 64 is expressing a  negative opinion about FOOD#QUALITY
# Review 65 is expressing a  positive opinion about FOOD#QUALITY
# Review 66 is expressing a  positive opinion about RESTAURANT#GENERAL
# Review 67 is expressing a  positive opinion about SERVICE#GENERAL
# Review 68 is expressing a  positive opinion about AMBIENCE#GENERAL
# Review 69 is expressing a  positive opinion about FOOD#QUALITY
# Review 70 is expressing a  positive opinion about AMBIENCE#GENERAL
# Review 71 is expressing a  positive opinion about FOOD#QUALITY
# Review 72 is expressing a  positive opinion about FOOD#QUALITY
# Review 73 is expressing a  negative opinion about FOOD#PRICES
# Review 74 is expressing a  positive opinion about RESTAURANT#GENERAL
# Review 75 is expressing a  positive opinion about FOOD#QUALITY
# Review 76 is expressing a  negative opinion about FOOD#QUALITY
# Review 77 is expressing a  positive opinion about FOOD#QUALITY
# Review 78 is expressing a  neutral opinion about FOOD#QUALITY
# Review 79 is expressing a  positive opinion about FOOD#QUALITY
# Review 80 is expressing a  positive opinion about SERVICE#GENERAL
# Review 81 is expressing a  positive opinion about SERVICE#GENERAL
# Review 82 is expressing a  negative opinion about FOOD#STYLE_OPTIONS
# Review 83 is expressing a  positive opinion about FOOD#QUALITY
# Review 84 is expressing a  positive opinion about SERVICE#GENERAL
# Review 85 is expressing a  negative opinion about FOOD#QUALITY
# Review 86 is expressing a  positive opinion about FOOD#QUALITY
# Review 87 is expressing a  positive opinion about FOOD#QUALITY
# Review 88 is expressing a  negative opinion about SERVICE#GENERAL
# Review 89 is expressing a  positive opinion about AMBIENCE#GENERAL
# Review 90 is expressing a  positive opinion about FOOD#QUALITY
# Review 91 is expressing a  negative opinion about FOOD#QUALITY
# Review 92 is expressing a  neutral opinion about FOOD#QUALITY
# Review 93 is expressing a  positive opinion about FOOD#QUALITY
# Review 94 is expressing a  negative opinion about AMBIENCE#GENERAL
# Review 95 is expressing a  positive opinion about FOOD#QUALITY
# Review 96 is expressing a  negative opinion about FOOD#QUALITY
# Review 97 is expressing a  positive opinion about FOOD#QUALITY
# Review 98 is expressing a  positive opinion about FOOD#QUALITY
# Review 99 is expressing a  positive opinion about SERVICE#GENERAL
# Review 100 is expressing a  positive opinion about RESTAURANT#GENERAL
# Review 101 is expressing a  positive opinion about RESTAURANT#GENERAL
# Review 102 is expressing a  negative opinion about FOOD#PRICES
# Review 103 is expressing a  positive opinion about SERVICE#GENERAL
# Review 104 is expressing a  negative opinion about FOOD#QUALITY
# Review 105 is expressing a  positive opinion about SERVICE#GENERAL
# Review 106 is expressing a  positive opinion about AMBIENCE#GENERAL
# Review 107 is expressing a  positive opinion about FOOD#QUALITY
# Review 108 is expressing a  neutral opinion about FOOD#QUALITY
# Review 109 is expressing a  negative opinion about RESTAURANT#GENERAL
# Review 110 is expressing a  positive opinion about RESTAURANT#GENERAL
# Review 111 is expressing a  positive opinion about RESTAURANT#PRICES
# Review 112 is expressing a  positive opinion about FOOD#QUALITY
# Review 113 is expressing a  positive opinion about SERVICE#GENERAL
# Review 114 is expressing a  positive opinion about RESTAURANT#GENERAL
# Review 115 is expressing a  negative opinion about DRINKS#STYLE_OPTIONS
# Review 116 is expressing a  positive opinion about RESTAURANT#GENERAL
# Review 117 is expressing a  positive opinion about FOOD#QUALITY
# Review 118 is expressing a  negative opinion about FOOD#QUALITY
# Review 119 is expressing a  negative opinion about FOOD#QUALITY
# Review 120 is expressing a  positive opinion about RESTAURANT#GENERAL
# Review 121 is expressing a  negative opinion about SERVICE#GENERAL
# Review 122 is expressing a  positive opinion about FOOD#QUALITY
# Review 123 is expressing a  positive opinion about FOOD#QUALITY
# Review 124 is expressing a  positive opinion about SERVICE#GENERAL
# Review 125 is expressing a  positive opinion about AMBIENCE#GENERAL
# Review 126 is expressing a  positive opinion about SERVICE#GENERAL
# Review 127 is expressing a  positive opinion about RESTAURANT#GENERAL
# Review 128 is expressing a  positive opinion about FOOD#QUALITY
# Review 129 is expressing a  positive opinion about RESTAURANT#GENERAL
# Review 130 is expressing a  positive opinion about FOOD#QUALITY
# Review 131 is expressing a  positive opinion about FOOD#QUALITY
# Review 132 is expressing a  positive opinion about FOOD#QUALITY
# Review 133 is expressing a  positive opinion about SERVICE#GENERAL
# Review 134 is expressing a  negative opinion about FOOD#QUALITY
# Review 135 is expressing a  positive opinion about SERVICE#GENERAL
# Review 136 is expressing a  positive opinion about SERVICE#GENERAL
# Review 137 is expressing a  positive opinion about LOCATION#GENERAL
# Review 138 is expressing a  positive opinion about FOOD#QUALITY
# Review 139 is expressing a  positive opinion about LOCATION#GENERAL
# Review 140 is expressing a  positive opinion about SERVICE#GENERAL
# Review 141 is expressing a  neutral opinion about FOOD#QUALITY
# Review 142 is expressing a  positive opinion about RESTAURANT#GENERAL
# Review 143 is expressing a  positive opinion about FOOD#QUALITY
# Review 144 is expressing a  positive opinion about SERVICE#GENERAL
# Review 145 is expressing a  positive opinion about FOOD#QUALITY
# Review 146 is expressing a  positive opinion about FOOD#QUALITY
# Review 147 is expressing a  positive opinion about FOOD#QUALITY
# Review 148 is expressing a  positive opinion about AMBIENCE#GENERAL
# Review 149 is expressing a  positive opinion about FOOD#QUALITY
# Review 150 is expressing a  positive opinion about RESTAURANT#GENERAL
# Review 151 is expressing a  positive opinion about AMBIENCE#GENERAL
# Review 152 is expressing a  positive opinion about FOOD#QUALITY
# Review 153 is expressing a  positive opinion about RESTAURANT#GENERAL
# Review 154 is expressing a  positive opinion about FOOD#QUALITY
# Review 155 is expressing a  positive opinion about SERVICE#GENERAL
# Review 156 is expressing a  positive opinion about SERVICE#GENERAL
# Review 157 is expressing a  positive opinion about RESTAURANT#GENERAL
# Review 158 is expressing a  positive opinion about FOOD#QUALITY
# Review 159 is expressing a  positive opinion about FOOD#QUALITY
# Review 160 is expressing a  negative opinion about RESTAURANT#MISCELLANEOUS
# Review 161 is expressing a  positive opinion about SERVICE#GENERAL
# Review 162 is expressing a  positive opinion about FOOD#QUALITY
# Review 163 is expressing a  negative opinion about AMBIENCE#GENERAL
# Review 164 is expressing a  positive opinion about FOOD#QUALITY
# Review 165 is expressing a  positive opinion about RESTAURANT#GENERAL
# Review 166 is expressing a  positive opinion about DRINKS#PRICES
# Review 167 is expressing a  positive opinion about FOOD#STYLE_OPTIONS
# Review 168 is expressing a  positive opinion about FOOD#QUALITY
# Review 169 is expressing a  positive opinion about AMBIENCE#GENERAL
# Review 170 is expressing a  positive opinion about SERVICE#GENERAL
# Review 171 is expressing a  positive opinion about FOOD#QUALITY
# Review 172 is expressing a  positive opinion about FOOD#QUALITY
# Review 173 is expressing a  positive opinion about FOOD#QUALITY
# Review 174 is expressing a  positive opinion about SERVICE#GENERAL
# Review 175 is expressing a  positive opinion about AMBIENCE#GENERAL
# Review 176 is expressing a  positive opinion about LOCATION#GENERAL
# Review 177 is expressing a  positive opinion about FOOD#PRICES
# Review 178 is expressing a  negative opinion about FOOD#QUALITY
# Review 179 is expressing a  positive opinion about FOOD#QUALITY
# Review 180 is expressing a  positive opinion about AMBIENCE#GENERAL
# Review 181 is expressing a  positive opinion about SERVICE#GENERAL
# Review 182 is expressing a  negative opinion about AMBIENCE#GENERAL
# Review 183 is expressing a  positive opinion about SERVICE#GENERAL
# Review 184 is expressing a  positive opinion about SERVICE#GENERAL
# Review 185 is expressing a  positive opinion about FOOD#QUALITY
# Review 186 is expressing a  positive opinion about SERVICE#GENERAL
# Review 187 is expressing a  positive opinion about DRINKS#PRICES
# Review 188 is expressing a  positive opinion about FOOD#QUALITY
# Review 189 is expressing a  negative opinion about SERVICE#GENERAL
# Review 190 is expressing a  positive opinion about RESTAURANT#GENERAL
# Review 191 is expressing a  negative opinion about SERVICE#GENERAL
# Review 192 is expressing a  positive opinion about AMBIENCE#GENERAL
# Review 193 is expressing a  positive opinion about FOOD#QUALITY
# Review 194 is expressing a  positive opinion about AMBIENCE#GENERAL
# Review 195 is expressing a  positive opinion about FOOD#QUALITY
# Review 196 is expressing a  negative opinion about FOOD#QUALITY
# Review 197 is expressing a  positive opinion about FOOD#QUALITY
# Review 198 is expressing a  positive opinion about FOOD#QUALITY
# Review 199 is expressing a  positive opinion about FOOD#QUALITY
# Review 200 is expressing a  positive opinion about FOOD#QUALITY
# Review 201 is expressing a  positive opinion about RESTAURANT#GENERAL
# Review 202 is expressing a  positive opinion about AMBIENCE#GENERAL
# Review 203 is expressing a  neutral opinion about RESTAURANT#GENERAL
# Review 204 is expressing a  positive opinion about SERVICE#GENERAL
# Review 205 is expressing a  positive opinion about RESTAURANT#MISCELLANEOUS
# Review 206 is expressing a  positive opinion about AMBIENCE#GENERAL
# Review 207 is expressing a  positive opinion about SERVICE#GENERAL
# Review 208 is expressing a  positive opinion about FOOD#STYLE_OPTIONS
# Review 209 is expressing a  positive opinion about FOOD#QUALITY
# Review 210 is expressing a  negative opinion about FOOD#QUALITY
# Review 211 is expressing a  negative opinion about AMBIENCE#GENERAL
# Review 212 is expressing a  positive opinion about FOOD#QUALITY
# Review 213 is expressing a  positive opinion about SERVICE#GENERAL
# Review 214 is expressing a  positive opinion about FOOD#QUALITY
# Review 215 is expressing a  positive opinion about LOCATION#GENERAL
# Review 216 is expressing a  positive opinion about FOOD#QUALITY
# Review 217 is expressing a  positive opinion about RESTAURANT#MISCELLANEOUS
# Review 218 is expressing a  positive opinion about AMBIENCE#GENERAL
# Review 219 is expressing a  positive opinion about RESTAURANT#GENERAL
# Review 220 is expressing a  negative opinion about FOOD#STYLE_OPTIONS
# Review 221 is expressing a  negative opinion about FOOD#QUALITY
# Review 222 is expressing a  positive opinion about AMBIENCE#GENERAL
# Review 223 is expressing a  positive opinion about RESTAURANT#PRICES
# Review 224 is expressing a  positive opinion about SERVICE#GENERAL
# Review 225 is expressing a  negative opinion about RESTAURANT#GENERAL
# Review 226 is expressing a  negative opinion about FOOD#QUALITY
# Review 227 is expressing a  positive opinion about DRINKS#PRICES
# Review 228 is expressing a  positive opinion about SERVICE#GENERAL
# Review 229 is expressing a  negative opinion about RESTAURANT#GENERAL
# Review 230 is expressing a  positive opinion about SERVICE#GENERAL
# Review 231 is expressing a  positive opinion about FOOD#QUALITY
# Review 232 is expressing a  positive opinion about FOOD#STYLE_OPTIONS
# Review 233 is expressing a  positive opinion about FOOD#QUALITY
# Review 234 is expressing a  positive opinion about FOOD#QUALITY
# Review 235 is expressing a  positive opinion about DRINKS#STYLE_OPTIONS
# Review 236 is expressing a  positive opinion about SERVICE#GENERAL
# Review 237 is expressing a  negative opinion about FOOD#QUALITY
# Review 238 is expressing a  positive opinion about FOOD#QUALITY
# Review 239 is expressing a  positive opinion about AMBIENCE#GENERAL
# Review 240 is expressing a  positive opinion about SERVICE#GENERAL
# Review 241 is expressing a  positive opinion about FOOD#QUALITY
# Review 242 is expressing a  positive opinion about FOOD#PRICES
# Review 243 is expressing a  positive opinion about SERVICE#GENERAL
# Review 244 is expressing a  negative opinion about FOOD#PRICES
# Review 245 is expressing a  negative opinion about FOOD#QUALITY
# Review 246 is expressing a  negative opinion about FOOD#QUALITY
# Review 247 is expressing a  positive opinion about AMBIENCE#GENERAL
# Review 248 is expressing a  positive opinion about AMBIENCE#GENERAL
# Review 249 is expressing a  positive opinion about RESTAURANT#GENERAL
# Review 250 is expressing a  positive opinion about AMBIENCE#GENERAL
# Review 251 is expressing a  positive opinion about DRINKS#PRICES
# Review 252 is expressing a  negative opinion about FOOD#QUALITY
# Review 253 is expressing a  negative opinion about FOOD#QUALITY
# Review 254 is expressing a  negative opinion about FOOD#QUALITY
# Review 255 is expressing a  negative opinion about FOOD#STYLE_OPTIONS
# Review 256 is expressing a  negative opinion about SERVICE#GENERAL
# Review 257 is expressing a  positive opinion about FOOD#QUALITY
# Review 258 is expressing a  neutral opinion about FOOD#QUALITY
# Review 259 is expressing a  negative opinion about FOOD#QUALITY
# Review 260 is expressing a  negative opinion about FOOD#QUALITY
# Review 261 is expressing a  positive opinion about FOOD#STYLE_OPTIONS
# Review 262 is expressing a  positive opinion about RESTAURANT#GENERAL
# Review 263 is expressing a  negative opinion about SERVICE#GENERAL
# Review 264 is expressing a  positive opinion about AMBIENCE#GENERAL
# Review 265 is expressing a  negative opinion about FOOD#STYLE_OPTIONS
# Review 266 is expressing a  positive opinion about RESTAURANT#GENERAL
# Review 267 is expressing a  negative opinion about RESTAURANT#MISCELLANEOUS
# Review 268 is expressing a  positive opinion about SERVICE#GENERAL
# Review 269 is expressing a  negative opinion about RESTAURANT#GENERAL
# Review 270 is expressing a  negative opinion about FOOD#QUALITY
# Review 271 is expressing a  negative opinion about AMBIENCE#GENERAL
# Review 272 is expressing a  negative opinion about FOOD#QUALITY
# Review 273 is expressing a  positive opinion about FOOD#QUALITY
# Review 274 is expressing a  positive opinion about FOOD#QUALITY
# Review 275 is expressing a  positive opinion about FOOD#QUALITY
# Review 276 is expressing a  positive opinion about FOOD#STYLE_OPTIONS
# Review 277 is expressing a  positive opinion about RESTAURANT#PRICES
# Review 278 is expressing a  negative opinion about FOOD#QUALITY
# Review 279 is expressing a  positive opinion about SERVICE#GENERAL
# Review 280 is expressing a  positive opinion about FOOD#QUALITY
# Review 281 is expressing a  neutral opinion about RESTAURANT#GENERAL
# Review 282 is expressing a  positive opinion about SERVICE#GENERAL
# Review 283 is expressing a  positive opinion about FOOD#QUALITY
# Review 284 is expressing a  negative opinion about FOOD#QUALITY
# Review 285 is expressing a  positive opinion about FOOD#PRICES
# Review 286 is expressing a  positive opinion about FOOD#QUALITY
# Review 287 is expressing a  positive opinion about FOOD#QUALITY
# Review 288 is expressing a  negative opinion about FOOD#STYLE_OPTIONS
# Review 289 is expressing a  positive opinion about FOOD#QUALITY
# Review 290 is expressing a  positive opinion about FOOD#QUALITY
# Review 291 is expressing a  positive opinion about FOOD#QUALITY
# Review 292 is expressing a  positive opinion about FOOD#QUALITY
# Review 293 is expressing a  positive opinion about RESTAURANT#GENERAL
# Review 294 is expressing a  positive opinion about FOOD#QUALITY
# Review 295 is expressing a  neutral opinion about RESTAURANT#PRICES
# Review 296 is expressing a  positive opinion about FOOD#QUALITY
# Review 297 is expressing a  positive opinion about FOOD#QUALITY
# Review 298 is expressing a  positive opinion about SERVICE#GENERAL
# Review 299 is expressing a  positive opinion about AMBIENCE#GENERAL
# Review 300 is expressing a  positive opinion about RESTAURANT#MISCELLANEOUS
# Review 301 is expressing a  negative opinion about FOOD#QUALITY
# Review 302 is expressing a  positive opinion about FOOD#QUALITY
# Review 303 is expressing a  negative opinion about FOOD#QUALITY
# Review 304 is expressing a  positive opinion about FOOD#QUALITY
# Review 305 is expressing a  positive opinion about FOOD#QUALITY
# Review 306 is expressing a  negative opinion about RESTAURANT#GENERAL
# Review 307 is expressing a  negative opinion about FOOD#QUALITY
# Review 308 is expressing a  negative opinion about RESTAURANT#GENERAL
# Review 309 is expressing a  positive opinion about AMBIENCE#GENERAL
# Review 310 is expressing a  negative opinion about FOOD#STYLE_OPTIONS
# Review 311 is expressing a  positive opinion about FOOD#QUALITY
# Review 312 is expressing a  negative opinion about FOOD#PRICES
# Review 313 is expressing a  positive opinion about DRINKS#STYLE_OPTIONS
# Review 314 is expressing a  positive opinion about FOOD#QUALITY
# Review 315 is expressing a  positive opinion about RESTAURANT#GENERAL
# Review 316 is expressing a  positive opinion about RESTAURANT#GENERAL
# Review 317 is expressing a  negative opinion about FOOD#QUALITY
# Review 318 is expressing a  negative opinion about DRINKS#PRICES
# Review 319 is expressing a  positive opinion about FOOD#QUALITY
# Review 320 is expressing a  positive opinion about SERVICE#GENERAL
# Review 321 is expressing a  positive opinion about SERVICE#GENERAL
# Review 322 is expressing a  positive opinion about RESTAURANT#GENERAL
# Review 323 is expressing a  positive opinion about FOOD#QUALITY
# Review 324 is expressing a  positive opinion about SERVICE#GENERAL
# Review 325 is expressing a  positive opinion about FOOD#QUALITY
# Review 326 is expressing a  neutral opinion about RESTAURANT#GENERAL
# Review 327 is expressing a  negative opinion about FOOD#QUALITY
# Review 328 is expressing a  positive opinion about RESTAURANT#GENERAL
# Review 329 is expressing a  positive opinion about DRINKS#PRICES
# Review 330 is expressing a  positive opinion about FOOD#STYLE_OPTIONS
# Review 331 is expressing a  positive opinion about RESTAURANT#GENERAL
# Review 332 is expressing a  positive opinion about SERVICE#GENERAL
# Review 333 is expressing a  positive opinion about FOOD#QUALITY
# Review 334 is expressing a  negative opinion about RESTAURANT#MISCELLANEOUS
# Review 335 is expressing a  positive opinion about FOOD#QUALITY
# Review 336 is expressing a  positive opinion about FOOD#QUALITY
# Review 337 is expressing a  positive opinion about AMBIENCE#GENERAL
# Review 338 is expressing a  positive opinion about SERVICE#GENERAL
# Review 339 is expressing a  positive opinion about SERVICE#GENERAL
# Review 340 is expressing a  negative opinion about RESTAURANT#GENERAL
# Review 341 is expressing a  positive opinion about FOOD#QUALITY
# Review 342 is expressing a  positive opinion about SERVICE#GENERAL
# Review 343 is expressing a  positive opinion about AMBIENCE#GENERAL
# Review 344 is expressing a  positive opinion about FOOD#QUALITY
# Review 345 is expressing a  positive opinion about RESTAURANT#MISCELLANEOUS
# Review 346 is expressing a  negative opinion about FOOD#QUALITY
# Review 347 is expressing a  positive opinion about SERVICE#GENERAL
# Review 348 is expressing a  positive opinion about RESTAURANT#GENERAL
# Review 349 is expressing a  positive opinion about FOOD#STYLE_OPTIONS
# Review 350 is expressing a  positive opinion about FOOD#QUALITY
# Review 351 is expressing a  positive opinion about FOOD#QUALITY
# Review 352 is expressing a  positive opinion about RESTAURANT#MISCELLANEOUS
# Review 353 is expressing a  positive opinion about FOOD#QUALITY
# Review 354 is expressing a  positive opinion about SERVICE#GENERAL
# Review 355 is expressing a  positive opinion about FOOD#QUALITY
# Review 356 is expressing a  positive opinion about FOOD#QUALITY
# Review 357 is expressing a  negative opinion about AMBIENCE#GENERAL
# Review 358 is expressing a  negative opinion about FOOD#QUALITY
# Review 359 is expressing a  negative opinion about RESTAURANT#GENERAL
# Review 360 is expressing a  positive opinion about FOOD#QUALITY
# Review 361 is expressing a  positive opinion about RESTAURANT#GENERAL
# Review 362 is expressing a  positive opinion about RESTAURANT#GENERAL
# Review 363 is expressing a  positive opinion about AMBIENCE#GENERAL
# Review 364 is expressing a  positive opinion about FOOD#QUALITY
# Review 365 is expressing a  neutral opinion about AMBIENCE#GENERAL
# Review 366 is expressing a  positive opinion about FOOD#STYLE_OPTIONS
# Review 367 is expressing a  positive opinion about RESTAURANT#PRICES
# Review 368 is expressing a  positive opinion about DRINKS#PRICES
# Review 369 is expressing a  positive opinion about FOOD#QUALITY
# Review 370 is expressing a  positive opinion about FOOD#QUALITY
# Review 371 is expressing a  negative opinion about FOOD#QUALITY
# Review 372 is expressing a  neutral opinion about RESTAURANT#GENERAL
# Review 373 is expressing a  positive opinion about RESTAURANT#MISCELLANEOUS
# Review 374 is expressing a  positive opinion about FOOD#QUALITY
# Review 375 is expressing a  negative opinion about FOOD#QUALITY
# Review 376 is expressing a  positive opinion about FOOD#QUALITY
# /home/ayush/anaconda2/envs/my_python_3/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:

# %% [markdown]
# ### Evaluation of the Predicted Sentiment Based on GroundTruth Data

# %%
def eval_list(glabels, slabels):
    if (len(glabels) != len(slabels)):
        print("\nWARNING: label count in system output (%d) is different from gold label count (%d)\n" % (
        len(slabels), len(glabels)))
    n = min(len(slabels), len(glabels))
    incorrect_count = 0
    for i in range(0, n):
        if slabels[i] != glabels[i]: incorrect_count += 1
    acc = (n - incorrect_count) / n
    print("\nACCURACY: %.2f" % (acc * 100))

# %%
#Predicted Polarity or Sentiment
slabels = list(Dev_predict_sentiment)

# GroundTruth Polarity or Sentiment
glabels = list(dev_df.Polarity)

print(len(slabels))
print(len(glabels))
# Out:
# 376
# 376

# %%
eval_list(glabels,slabels)
# Out:
# ACCURACY: 74.20
